# %% [markdown]
# <a href="https://colab.research.google.com/github/0megaAD/Aulasfiap/blob/main/MediaFIAP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🎓 Desafio: Cálculo de Média FIAP
# > Status do Projeto: 🟢 Concluído
#
# Este projeto tem como objetivo automatizar o cálculo da média acadêmica seguindo os critérios oficiais da **FIAP**, garantindo precisão e agilidade para os estudantes.
#
# ---
#
# ## 📋 Regras de Negócio
# Para calcular a média final, consideramos os seguintes pesos e componentes:
#
#
# | Componente | Sigla | Peso | Descrição |
# | :--- | :---: | :---: | :--- |
# | **Checkpoints** | CP | 20% | Média das provas e atividades de ciclo. |
# | **Global Solution** | GS | 60% | Prova semestral integradora. |
# | **Challenge** | CH | 20% | Projeto prático em parceria com empresas. |
#
# ---
#
# ## 🧮 Fórmula de Cálculo
# A média é calculada utilizando a média aritmética ponderada:
#
# ```math
# Média = (CP \times 0.2) + (GS \times 0.6) + (CH \times 0.2)

# %%
def calcularmediafiap():
  print("ola")
